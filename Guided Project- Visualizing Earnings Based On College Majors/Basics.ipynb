# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

recent_grads = pd.read_csv('recent-grads.csv')

print(recent_grads.iloc[0])
print(recent_grads.head(5))
print(recent_grads.tail(5))
recent_grads.describe()

raw_data_count = recent_grads.shape[0]
print(raw_data_count)
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
print(cleaned_data_count)
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter',
                      title='Sample_size vs. Median', figsize=(5,5))

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter',
                      title='Sample_size vs. Unemployment_rate', figsize=(5,5))

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter',
                      title='Full_time vs. Median', figsize=(5,5))

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter',
                      title='ShareWomen vs. Unemployment_rate', figsize=(5,5))

# %%
recent_grads.plot(x='ShareWomen', y='Median', kind='scatter',
                      title='ShareWomen vs. Median', figsize=(5,5))

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter',
                      title='Men vs. Median', figsize=(5,5))

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter',
                      title='Women vs. Median', figsize=(5,5))

# %% [markdown]
# 1. sample size inc => the median doesn't seem to be larger
# 2. No, less
# 3. the more full time employees there are, the less likely to earn high salary (according to the median salary assuming the std is similar)

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Median'].hist(bins=25, range=(0,100000))

# %%
recent_grads['Employed'].hist(bins=25, range=(0,100000))

# %%
recent_grads['Full_time'].hist(bins=25, range=(0,100000))

# %%
recent_grads['ShareWomen'].hist(bins=20, range=(0,1))

# %%
recent_grads['Unemployment_rate'].hist(bins=25, range=(0,1))

# %%
recent_grads['Men'].hist(bins=25, range=(0,100000))

# %%
recent_grads['Women'].hist(bins=25, range=(0,100000))

# %%
import pandas.tools.plotting as pd_tool_plot
pd_tool_plot.scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3125ddc240>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3125c90a90>]], dtype=object)

# %%
pd_tool_plot.scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3125bc1b00>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f312598a9b0>]], dtype=object)

# %%
pd_tool_plot.scatter_matrix(recent_grads[['Men', 'Women']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3125883f98>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f312583a358>]], dtype=object)

# %%
pd_tool_plot.scatter_matrix(recent_grads[['Men', 'Women','Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3125771668>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3125538f60>]], dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')
recent_grads[recent_grads.shape[0]-10:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')
recent_grads[recent_grads.shape[0]-10:].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[:10].plot.bar(x='Major', y=['Men','Women'], stacked=True)
recent_grads[recent_grads.shape[0]-10:].plot.bar(x='Major', y=['Men','Women'], stacked=True)

# %%
recent_grads.plot.box(y="Median")
recent_grads.plot.box(y="Unemployment_rate")

# %%
import numpy as np
recent_grads.plot.hexbin(x='Men', y='Median', gridsize=25, reduce_C_function=np.max)
recent_grads.plot.hexbin(x='Women', y='Median', gridsize=25, reduce_C_function=np.max)
